# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/vinay/OneDrive/Desktop/Python Programming/Learning/BigData/DAL-588-Big-Data-Project/Dataset/recipe_data_with_Eng_name.xlsx')

# %%
df.head()
# Out:
#   recipe_data                   Unnamed: 1  \
# 0   recipe_id                  recipe_name
# 1      708013                         Rice
# 2      800033  Tender and Moist Roast Beef
# 3      709927          Flavored Roast Beef
# 4      709224  Beef Soboro Rice with Broth
#
#                                           Unnamed: 2    Unnamed: 3  \
# 0                                            img_url   author_type
# 1                                                NaN  Organization
# 2  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
# 3  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
# 4  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
#
#        Unnamed: 4          Unnamed: 5         Unnamed: 6  \
# 0     author_name  published_datetime  modified_datetime
# 1  AJINOMOTO PARK          2022-03-15         2022-03-15
# 2  AJINOMOTO PARK          2018-03-06         2021-08-13
# 3  AJINOMOTO PARK          2018-03-06         2021-08-20
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# 0 recipe_id                              recipe_name  \
# 0    708013                                     Rice
# 1    800033              Tender and Moist Roast Beef
# 2    709927                      Flavored Roast Beef
# 3    709224              Beef Soboro Rice with Broth
# 4    709084  Sukiyaki-style Beef and Chinese Cabbage
#
# 0                                            img_url   author_type  \
# 0                                                NaN  Organization
# 1  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
# 2  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
# 3  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
# 4  https://park.ajinomoto.co.jp/wp-content/upload...  Organization
#
# 0     author_name published_datetime modified_datetime  \
# 0  AJINOMOTO PARK         2022-03-15        2022-03-15
# 1  AJINOMOTO PARK         2018-03-06        2021-08-13
# 2  AJINOMOTO PARK         2018-03-06        2021-08-20
# ...

# %%
df.columns
# Out:
# Index(['recipe_id', 'recipe_name', 'img_url', 'author_type', 'author_name',
#        'published_datetime', 'modified_datetime', 'recipe_description',
#        'servings', 'cooking_time', 'instructions', 'recipe_cuisine',
#        'nutrition', 'keywords', 'cliped_count', 'search_word',
#        'modified_ingredients', 'nutrients', 'GHG_production', 'price',
#        'disposal_amount', 'GHG_disposal', 'GHG_cooking', 'GHG_total', 'dish',
#        'ingredients_category', 'category', 'cooking_method', 'Energy (g)',
#        'Fat (g)', 'carbohydrates (g)', 'zinc (mg)', 'Folic acid (μg)',
#        'Protein (g)', 'Total fiber (g)', 'Vitamin A (μg)', 'Vitamin C (mg)',
#        'Vitamin E (mg)', 'Calcium (mg)', 'iron (mg)', 'Potassium (mg)',
#        'Magnesium (mg)', 'Saturated fat (g)', 'cholesterol (g)',
#        'Salt equivalent (g)'],
#       dtype='object', name=0)

# %%
df.shape
# Out:
# (388, 45)
